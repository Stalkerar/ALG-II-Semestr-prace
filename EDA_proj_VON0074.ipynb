# %% [markdown]
# <a href="https://colab.research.google.com/github/Stalkerar/ALG-II-Semestr-prace/blob/main/EDA_proj_VON0074.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA) of Social, gender and study data from secondary school students
#
# Data source: https://www.kaggle.com/uciml/student-alcohol-consumption?select=student-por.csv
#
#
# Important attributes description:
# * school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# * sex - student's sex (binary: 'F' - female or 'M' - male)
# * age - student's age (numeric: from 15 to 22)
# * address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# * Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# * Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# * studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# * failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * schoolsup - extra educational support (binary: yes or no)
# * famsup - family educational support (binary: yes or no)
# * paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * activities - extra-curricular activities (binary: yes or no)
# * nursery - attended nursery school (binary: yes or no)
# * higher - wants to take higher education (binary: yes or no)
# * internet - Internet access at home (binary: yes or no)
# * romantic - with a romantic relationship (binary: yes or no)
# * famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * health - current health status (numeric: from 1 - very bad to 5 - very good)
# * absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# * G1 - first period grade (numeric: from 0 to 20)
# * G2 - second period grade (numeric: from 0 to 20)
# * G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Import used packages

# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use

# %% [markdown]
# ## The first step is to load the data into the Pandas DataFrame - in our case it is a csv file

# %%
df = pd.read_csv('student-por.csv', sep=',')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Row and column count

# %%
df_full.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-471f0a8694a3> in <module>
# ----> 1 df_full.shape
#
# NameError: name 'df_full' is not defined

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# #### Datatypes of columns

# %%
df_full.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-89ee04c02a54> in <module>
# ----> 1 df_full.dtypes
#
# NameError: name 'df_full' is not defined

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# # Visualization

# %%
correlation = df.corr()

fig, ax = plt.subplots(figsize=(30,30)) 
hm = sns.heatmap(correlation, annot=True)
#hm.set_xticklabels(hm.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# **Description:** Základní rozdělení studentů dle školy a následně dle věku,  pohlaví a jejich počet.

# %%
sns.displot(data=df, x='age',col='school',hue='sex')

# %% [markdown]
# **Insight gained:** Vidíme, že na školu Gabriel Pereira chodí více studentů, na obou školách početně dominují ženy a nejpočetnější věkové skupiny jsou 16 - 18 let.

# %% [markdown]
# **Description:** Porovnání důvodů výběru školy.

# %%
df_gp = df[df['school'] == 'GP']
df_ms = df[df['school'] == 'MS']


fig = plt.figure(figsize=(12,6))
plt.pie(df_gp['reason'].value_counts(),labels=set(df_gp["reason"]),autopct='%1.1f%%')
plt.title('Reason to choose Gabriel Pereira school (%)')
plt.show()

fig = plt.figure(figsize=(12,6))
plt.pie(df_ms['reason'].value_counts(),labels=set(df_ms["reason"]),autopct='%1.1f%%')
plt.title('Reason to choose Mousinho da Silveira school (%)')
plt.show()

# %% [markdown]
# **Insight gained:** Z grafů lze vyčíst že reputace hraje v obou případech důležitou roli a, že škola Mousinho da Silveira je považována za lehce prestižnější, ale Gabriel Pereira má oblíbenější podobu předmětu a zdá se i lepší lokalitu.

# %% [markdown]
# **Description:** Porovnání škol v docházce.

# %%
sns.boxplot(x="school", y="absences", data=df)

# %%
sns.boxplot(x="school", y="health", data=df)

# %% [markdown]
# **Description:** Z prvního grafu lze vidět, že studenti GP školy mají větší absenci i přesto, že na MS školu dochází více studentů s horším zdravím (graf 2.).

# %%
sns.boxplot(x="school", y="G3", data=df)

# %% [markdown]
# Kdo je více úspěšný Moje

# %% [markdown]
# **Description:** Rozdil konzumace alkoholu behem vikendu mezi pohlavim a adresou
#
# **Insight gained:** Z grafu muzeme videt, ze muzi konzumuji vyrazne vice alkoholu nez zeny, a take, ze vice alkoholu konzumuji lide z mesta

# %%
sns.displot(data=df, x='famrel', col='school',hue='Pstatus', edgecolor='white')

# %% [markdown]
# **Description:** Ma podpora vzdelani v rodine vliv na pokracovani ve vyssim vzdelani
#
# **Insight gained:** Data z grafu ukazuji, ze studenti s podporou vzdelani v rodine chteji vyssi vzdelani

# %%
#plt.scatter(df.famsup, df.higher)
sns.displot(data=df, x='higher', col='school', edgecolor='white')

# %% [markdown]
# **Description:** Kolik studentu chce pokracovat na vyssi vzdelani?
#
# **Insight gained:** Z grafu vidime, ze vetsina studentu chce pokracovat ve vzdelavani

# %%
s_ca = df.groupby('higher').higher.count()
plt.bar(x=s_ca.index, height=s_ca.values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **Description:** Roste spolus vekem i prumerna konzumace alkoholu?
#
# **Insight gained:** Z grafu bych usoudil, ze ano.

# %%
avg_c = df.groupby('age').Dalc.mean().reset_index(name='AvgConsumption')
plt.figure(figsize=(9,6))
sns.lineplot(data=avg_c, x='age', y='AvgConsumption')
# Out:
# <AxesSubplot:xlabel='age', ylabel='AvgConsumption'>

# %% [markdown]
# **Description:** Jaky je vliv partnerstvi rodicu na konzumaci alkoholu?
#
# **Insight gained:** Dle grafu usuzuji, ze to, zdali jsou rodice studenta rozvedeni ci ne, nema na konzumaci alkoholu vliv

# %%
sns.boxplot(x="Pstatus", y="Walc", data=df)
# Out:
# <AxesSubplot:xlabel='Pstatus', ylabel='Walc'>

# %% [markdown]
# **Description:** Piji studenti, kteri se vice venuji studiu vice nebo mene?
#
# **Insight gained:** Podle grafu bych rekl, ze studenti, ktery se vice uci, konzumuji mene alkoholu.
#                     To muze byt zpusobeno, bud tim, ze maji mene casu, nebo protoze se alkoholu vyhibaji

# %%
sns.boxplot(x="studytime", y="Dalc", data=df)
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='Dalc'>

# %% [markdown]
# **Description:** Ma absence nejaky vliv na znamky?
#
# **Insight gained:** Rekl bych, ze absence ma na znamky minimalni vliv

# %%
plt.scatter(df['absences'],df['G3'])
plt.xlabel('absence')
plt.ylabel('grades')
# Out:
# Text(0, 0.5, 'grades')

# %% [markdown]
# **Description:** Ma konzumace alkoholu vliv na prospech studenta?
#
# **Insight gained:** V grafu vidime, ze uspesni studenti moc alkoholu nekonzumuji

# %%
plot = sns.lineplot(x="G3", y="Dalc", data=df)

plot.set(xlabel="Final Grade", ylabel="Alcohol Consumption")
# Out:
# [Text(0.5, 0, 'Final Grade'), Text(0, 0.5, 'Alcohol Consumption')]

# %%
data = df
ave = sum(data.G3)/float(len(data))
data['average'] = ['above' if i > ave else 'under' for i in data.G3]
sns.swarmplot(x='Dalc', y = 'G3', hue = 'average',data= data,palette={'above':'lime', 'under': 'red'})
# Out:
# C:\Users\PC\Desktop\ZSU\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\PC\Desktop\ZSU\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\PC\Desktop\ZSU\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Dalc', ylabel='G3'>

# %%
sns.displot(df.G3)

# %% [markdown]
# ## Conclusion
#
# Ackoliv studenti, kteri jsou ve studiich uspesnejsi konzumuji mene alkoholu, z analyzovanych dat jsem dosel k zaveru, ze konzumace alkoholu nema na vzdelani a vysledky studentu vliv.
